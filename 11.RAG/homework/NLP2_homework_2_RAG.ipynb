# %% [markdown]
# # Домашнее задание: Retrieval-Augmented Generation (RAG)
#
# **Курс:** NLP-2
# **Тема:** Построение, оптимизация и комплексная оценка RAG-систем.
#
# ## Введение
# В рамках данного задания вам предстоит пройти полный путь ML-инженера при работе с RAG: от сборки базового пайплайна до тонкой настройки ретривера и генератора. Мы будем работать с датасетом **SciFact** (проверка научных фактов).
#
# ### Методология Эксперимента
# Важно соблюдать гигиену ML-экспериментов. Мы разделили данные на два сета:
# 1.  **Main Split (200 запросов):** Ваша "Dev" выборка. Все промежуточные прогоны, подбор гиперпараметров (chunk size, top_k) и отладку вы делаете **только** на ней. Мы хотим избежать переобучения под тестовые данные.
# 2.  **Challenge Split (50 запросов):** Ваша "Test" выборка. Вы используете её **ровно один раз** в самом конце ноутбука для финальной валидации лучшей конфигурации.
#
# ---

# %% [markdown]
# ## 1. Подготовка окружения
# Установка зависимостей. Мы используем `LlamaIndex` как оркестратор, `Qdrant` как векторную БД и `HuggingFace` для моделей.

# %%
# %%capture
# !pip install llama-index-core llama-index-llms-huggingface llama-index-embeddings-huggingface llama-index-vector-stores-qdrant llama-index-retrievers-bm25 llama-index-llms-openai
# !pip install qdrant-client ir_datasets ir_measures bitsandbytes accelerate transformers
# !pip install pandas matplotlib seaborn tqdm

# %%
# JAX Memory Configuration (CRITICAL: must run before imports)
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "platform"
print("JAX configured")
# Out:
# JAX configured

# %%
import os
import time
import random
import gc
from dataclasses import dataclass, field
from typing import List, Optional, Dict

import numpy as np
import pandas as pd
import torch
from tqdm.auto import tqdm

# Optimizations for T4 GPU in Colab
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

ARTIFACTS_DIR = "/content/artifacts"
QDRANT_PATH = f"{ARTIFACTS_DIR}/qdrant_local"
LOGS_DIR = f"{ARTIFACTS_DIR}/logs"

os.makedirs(QDRANT_PATH, exist_ok=True)
os.makedirs(LOGS_DIR, exist_ok=True)

# %% [markdown]
# ## 2. Загрузка данных (SciFact)
# Загружаем корпус и запросы. SciFact — это сложный датасет, где запрос часто требует понимания причинно-следственных связей в научных текстах.

# %%
import ir_datasets

ds_corpus = ir_datasets.load("beir/scifact")
ds_test = ir_datasets.load("beir/scifact/test")

print("Loading corpus...")
corpus_rows = [{"doc_id": str(d.doc_id), "title": d.title or "", "text": d.text or ""} for d in ds_corpus.docs_iter()]
df_corpus = pd.DataFrame(corpus_rows)

print("Loading queries...")
query_rows = [{"query_id": str(q.query_id), "text": q.text} for q in ds_test.queries_iter()]
df_queries = pd.DataFrame(query_rows)

print("Loading qrels...")
qrel_rows = [{"query_id": str(q.query_id), "corpus_id": str(q.doc_id), "score": int(q.relevance)} for q in ds_test.qrels_iter()]
df_qrels = pd.DataFrame(qrel_rows)

# Map for metrics calculation
qrels_map = df_qrels.groupby("query_id").apply(lambda x: dict(zip(x["corpus_id"], x["score"]))).to_dict()

# Fixed Splits
all_qids = df_queries["query_id"].unique()
rng = np.random.default_rng(42)
rng.shuffle(all_qids)
split_main = all_qids[:200]
split_challenge = all_qids[200:250]

print(f"Corpus size: {len(df_corpus)}")
print(f"Main split: {len(split_main)} queries, Challenge split: {len(split_challenge)} queries")
# Out:
# [INFO] [starting] building docstore
# Loading corpus...
# [INFO] [starting] opening zip file
# [INFO] [starting] https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip
# docs_iter:   0%|                                      | 0/5183 [00:01<?, ?doc/s]
# https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip: 0.0%| 0.00/2.82M [00:00<?, ?B/s]
# https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip: 2.9%| 81.9k/2.82M [00:00<00:06, 425kB/s]
# https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip: 8.7%| 246k/2.82M [00:00<00:03, 821kB/s]
# https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip: 23.6%| 664k/2.82M [00:00<00:01, 1.65MB/s]
# https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip: 46.8%| 1.32M/2.82M [00:00<00:00, 2.61MB/s]
#
# [INFO] [finished] https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip: [00:00] [2.82MB] [4.11MB/s]
# docs_iter:   0%|                                      | 0/5183 [00:01<?, ?doc/s]
# https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip: [00:00] [2.82MB] [3.98MB/s]
# [INFO] [finished] opening zip file [1.86s]
# docs_iter: 100%|█████████████████████████| 5183/5183 [00:02<00:00, 2150.01doc/s]
# [INFO] [finished] docs_iter: [00:02] [5183doc] [2147.31doc/s]
# [INFO] [finished] building docstore [2.42s]
# [INFO] [starting] opening zip file
# [INFO] [finished] opening zip file s]
# [INFO] [starting] opening zip file
# [INFO] [finished] opening zip file s]
# /tmp/ipython-input-2705820492.py:19: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   qrels_map = df_qrels.groupby("query_id").apply(lambda x: dict(zip(x["corpus_id"], x["score"]))).to_dict()
# Loading queries...
# Loading qrels...
# Corpus size: 5183
# Main split: 200 queries, Challenge split: 50 queries

# %% [markdown]
# ## 3. Конфигурация и Модели
# Мы используем `dataclasses` для строгой типизации конфигов экспериментов.

# %%
from llama_index.core import VectorStoreIndex, Document, Settings, StorageContext
from llama_index.vector_stores.qdrant import QdrantVectorStore
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.huggingface import HuggingFaceLLM
from llama_index.core.node_parser import SentenceSplitter, HierarchicalNodeParser
from llama_index.core.retrievers import QueryFusionRetriever
from llama_index.retrievers.bm25 import BM25Retriever
from qdrant_client import QdrantClient
from transformers import BitsAndBytesConfig, AutoTokenizer

# --- CONFIG CLASSES ---
@dataclass
class ChunkingConfig:
    chunk_size: int = 512
    chunk_overlap: int = 100
    use_hierarchical: bool = False
    child_chunk_size: int = 128

@dataclass
class RetrievalConfig:
    top_k: int = 5          # Final k documents for LLM
    overfetch_k: int = 15   # Candidates fetched from DB (The "Funnel" top)
    mode: str = "dense"     # "dense" | "hybrid"
    use_reranker: bool = False
    rerank_top_n: int = 5   # Documents to keep after reranking

@dataclass
class LLMConfig:
    model_name: str = "Qwen/Qwen3-4B-Instruct-2507"
    max_new_tokens: int = 256
    context_window: int = 2048
    load_in_4bit: bool = True
    # Subsample for E2E evaluation speed
    e2e_eval_n: int = 10
    prompt_template: str = "Context:\n{context_str}\n\nQuery: {query_str}\nAnswer:"

@dataclass
class EmbeddingConfig:
    model_name: str = "Qwen/Qwen3-Embedding-0.6B"
    truncate_dim: Optional[int] = None # For Matryoshka learning

@dataclass
class RAGConfig:
    name: str = "baseline"
    chunking: ChunkingConfig = field(default_factory=ChunkingConfig)
    retrieval: RetrievalConfig = field(default_factory=RetrievalConfig)
    llm: LLMConfig = field(default_factory=LLMConfig)
    embedding: EmbeddingConfig = field(default_factory=EmbeddingConfig)
    qdrant_collection: str = "scifact_dense_base"
    recreate_collection: bool = False
    rerank_model: str = "Qwen/Qwen3-Reranker-0.6B"

# --- MODEL HELPERS ---
_CACHED_LLM = None
_CACHED_EMBED = None

def unload_embedder():
    global _CACHED_EMBED
    if _CACHED_EMBED:
        del _CACHED_EMBED
        _CACHED_EMBED = None
        Settings.embed_model = None
        gc.collect(); torch.cuda.empty_cache()

def get_embedder(cfg: EmbeddingConfig):
    global _CACHED_EMBED
    if _CACHED_EMBED: return _CACHED_EMBED
    _CACHED_EMBED = HuggingFaceEmbedding(
        model_name=cfg.model_name,
        device="cuda",
        normalize=True,
        truncate_dim=cfg.truncate_dim
    )
    return _CACHED_EMBED

def get_llm(cfg: LLMConfig):
    global _CACHED_LLM
    if _CACHED_LLM: return _CACHED_LLM
    tokenizer = AutoTokenizer.from_pretrained(
        cfg.model_name,
        trust_remote_code=True,
        use_fast=True,
    )

    bnb = BitsAndBytesConfig(load_in_4bit=True, bnb_4bit_compute_dtype=torch.bfloat16, bnb_4bit_quant_type="nf4")
    _CACHED_LLM = HuggingFaceLLM(
        model_name=cfg.model_name,
        context_window=cfg.context_window,
        tokenizer_name=cfg.model_name,
        tokenizer=tokenizer,
        max_new_tokens=cfg.max_new_tokens,
        model_kwargs={"quantization_config": bnb},
        generate_kwargs={"do_sample": False},
        device_map="auto"
    )
    return _CACHED_LLM

# %% [markdown]
# ## 4. Система Метрик (Metrics System)
#
# Для комплексной оценки качества мы используем двухуровневую систему метрик.
#
# ### 1. Retrieval Phase (Поиск)
# Оценивает, насколько релевантные куски текста (chunks) мы нашли в базе.
#
# **A. С учителем (Supervised / Reference-based):**
# Требуют наличия "правильных ответов" (qrels).
# *   **`nDCG@k`**: Основная метрика ранжирования. Учитывает не только факт нахождения правильного документа, но и его позицию (чем выше, тем лучше).
# *   **`Recall@k`**: Полнота. Какую долю всех релевантных документов мы нашли в топ-k.
#
# **B. Без учителя (Unsupervised / Reference-free):**
# Полезны для мониторинга в продакшене, где нет разметки.
# *   **`Mean Relevance Score`**: Среднее значение скора (similarity), который выдает ретривер. Показывает "уверенность" модели в найденном.
# *   **`Redundancy`**: Избыточность. Показывает, насколько найденные чанки похожи друг на друга. Высокая избыточность — плохо (мы хотим разнообразный контекст).
#
# ### 2. Generation Phase (Генерация)
# Оценивает качество финального ответа с использованием **LLM-as-a-Judge** (одна LLM оценивает другую).
#
# *   **`Faithfulness` (Answer vs Context):** Верность контексту. Проверяет, что ответ сгенерирован **исключительно** на основе найденных документов, без галлюцинаций.
# *   **`Answer Relevancy` (Answer vs Query):** Релевантность вопроса. Проверяет, что сгенерированный текст действительно отвечает на поставленный вопрос пользователя.

# %%
import ir_measures
from ir_measures import nDCG, Recall, RR

RUNS_CSV_PATH = os.path.join(LOGS_DIR, "runs.csv")

def compute_redundancy(contexts: List[str]) -> float:
    """Calculates semantic redundancy (higher = more duplicate info)."""
    if not contexts: return 0.0
    unique = len(set(contexts))
    return 1.0 - (unique / len(contexts))

def compute_retrieval_metrics(qrels_map, run_doc_ids, run_contexts, run_scores, k=5):
    # 1. Reference-based Metrics (Ground Truth needed)
    run_ir = {}
    for qid, doc_ids in run_doc_ids.items():
        run_ir[qid] = {doc_id: float(-(rank + 1)) for rank, doc_id in enumerate(doc_ids[:k])}

    measures = [nDCG@k, Recall@k]
    agg = ir_measures.calc_aggregate(measures, qrels_map, run_ir)

    # 2. Reference-free Metrics (No Ground Truth)
    red_vals = [compute_redundancy(ctxs[:k]) for ctxs in run_contexts.values()]
    # Mean Score: How confident is the retriever?
    score_vals = [np.mean(scores[:k]) for scores in run_scores.values() if scores]

    return {
        "ndcg@k": float(agg[nDCG@k]),
        "recall@k": float(agg[Recall@k]),
        "ref_free_mean_score": float(np.mean(score_vals)) if score_vals else 0.0,
        "ref_free_redundancy": float(np.mean(red_vals)) if red_vals else 0.0
    }

def log_run(cfg, split, stage, run_name, metrics):
    row = {
        "ts": time.strftime("%H:%M:%S", time.gmtime()),
        "run_name": run_name,
        "split": split,
        "stage": stage,
        **metrics
    }
    df_old = pd.read_csv(RUNS_CSV_PATH) if os.path.exists(RUNS_CSV_PATH) else pd.DataFrame()
    pd.concat([df_old, pd.DataFrame([row])], ignore_index=True).to_csv(RUNS_CSV_PATH, index=False)

def show_leaderboard(stage="retrieval", split="main"):
    if not os.path.exists(RUNS_CSV_PATH): return
    df = pd.read_csv(RUNS_CSV_PATH)
    df_sub = df[(df["stage"]==stage) & (df["split"]==split)].copy()
    if df_sub.empty: return

    # Sort by key metric
    sort_col = "ndcg@k" if stage == "retrieval" else "faithfulness"
    if sort_col in df_sub.columns:
        df_sub = df_sub.sort_values(sort_col, ascending=False)

    # Select columns to display
    cols_ret = ["run_name", "ndcg@k", "recall@k", "ref_free_mean_score", "ref_free_redundancy", "latency_s"]
    cols_gen = ["run_name", "faithfulness", "answer_relevancy", "latency_s"]

    cols = cols_ret if stage == "retrieval" else cols_gen
    print(f"\n🏆 LEADERBOARD [{stage.upper()} | {split.upper()}] 🏆")
    display(df_sub[[c for c in cols if c in df_sub.columns]])

def _get_df(split): return df_queries[df_queries["query_id"].isin(split_main if split=="main" else split_challenge)]

def run_retrieval(cfg: RAGConfig, split: str, run_name: str):
    # unload_embedder()
    index, retriever, _, client = build_rag_pipeline(cfg, df_corpus, load_llm=False)

    df_q = _get_df(split)
    results_dids, results_txts, results_scores = {}, {}, {}

    t0 = time.time()
    for row in tqdm(df_q.itertuples(index=False), total=len(df_q), desc=f"Retr {run_name}"):
        nodes = retriever.retrieve(row.text)
        # De-duplicate by doc_id to avoid metrics skew
        seen, dids, txts, scores = set(), [], [], []
        for n in nodes:
            if n.metadata["doc_id"] not in seen:
                seen.add(n.metadata["doc_id"])
                dids.append(n.metadata["doc_id"])
                txts.append(n.get_text())
                scores.append(n.score if n.score else 0.0)
        results_dids[str(row.query_id)] = dids
        results_txts[str(row.query_id)] = txts
        results_scores[str(row.query_id)] = scores

    # FIX: filter qrels_map based on current split
    split_qids = set(df_q["query_id"].astype(str))
    qrels_map_filtered = {qid: docs for qid, docs in qrels_map.items() if qid in split_qids}

    latency = time.time() - t0

    metrics = compute_retrieval_metrics(qrels_map_filtered, results_dids, results_txts, results_scores, k=cfg.retrieval.top_k)
    metrics["latency_s"] = latency
    log_run(cfg, split, "retrieval", run_name, metrics)
    show_leaderboard("retrieval", split)
    unload_embedder()
    client.close()

def run_generation(cfg: RAGConfig, split: str, run_name: str):
    """Generates answers and saves them to JSON for subsequent evaluation."""
    # 1. Retrieval Phase
    # unload_embedder()
    index, retriever, _, client = build_rag_pipeline(cfg, df_corpus, load_llm=False)
    df_q = _get_df(split).head(cfg.llm.e2e_eval_n)
    records = []
    for row in tqdm(df_q.itertuples(index=False), total=len(df_q), desc="Retrieving Contexts"):
        nodes = retriever.retrieve(row.text)
        ctx_list = [n.get_text() for n in nodes[:cfg.retrieval.top_k]]
        records.append({"query_id": str(row.query_id), "q": row.text, "ctx": "\n".join(ctx_list)})

    unload_embedder()

    # 2. Generation Phase
    Settings.embed_model = None
    llm = get_llm(cfg.llm)

    t0 = time.time()
    for item in tqdm(records, desc="Generating"):
        prompt = cfg.llm.prompt_template.format(context_str=item["ctx"], query_str=item["q"])
        try:
            item["a"] = llm.complete(prompt).text
        except:
            item["a"] = ""
    latency = time.time() - t0

    # 3. Save results
    output_path = os.path.join(LOGS_DIR, f"generations_{run_name}_{split}.json")
    import json
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump({
            "records": records,
            "latency_s": latency,
            "cfg_name": cfg.name,
            "run_name": run_name,
            "split": split
        }, f, ensure_ascii=False, indent=2)

    print(f"✅ Generations saved to {output_path}")
    client.close()
    return output_path


def run_evaluation(generation_file: str, eval_name: Optional[str] = None):
    """Evaluates already generated answers."""
    import json

    # Load generated data
    with open(generation_file, 'r', encoding='utf-8') as f:
        data = json.load(f)

    records = data["records"]
    latency = data["latency_s"]
    split = data.get("split", "main")
    run_name = eval_name if eval_name else data.get("run_name", "eval")

    # Load LLM for Judge
    Settings.embed_model = None
    llm = get_llm(LLMConfig())

    # Judge Phase
    faith_scores = []
    rel_scores = []

    for item in tqdm(records, desc=f"Judging {run_name}"):
        if not item.get("a", ""):
            faith_scores.append(0.0); rel_scores.append(0.0)
            continue

        # Metric 1: Faithfulness (Context vs Answer)
        p_faith = f"Context: {item['ctx'][:1000]}\nAnswer: {item['a']}\nDoes the Answer use the Context? YES/NO."
        res_f = llm.complete(p_faith, max_new_tokens=5).text.upper()
        faith_scores.append(1.0 if "YES" in res_f else 0.0)

        # Metric 2: Answer Relevancy (Question vs Answer)
        p_rel = f"Question: {item['q']}\nAnswer: {item['a']}\nDoes the Answer address the Question? YES/NO."
        res_r = llm.complete(p_rel, max_new_tokens=5).text.upper()
        rel_scores.append(1.0 if "YES" in res_r else 0.0)

    metrics = {
        "faithfulness": np.mean(faith_scores),
        "answer_relevancy": np.mean(rel_scores),
        "latency_s": latency
    }

    log_run(RAGConfig(name=run_name), split, "e2e", run_name, metrics)
    show_leaderboard("e2e", split)
    return metrics


def run_e2e(cfg: RAGConfig, split: str, run_name: str, generation_file: Optional[str] = None):
    """
    End-to-end evaluation with option to reuse generations.

    Args:
        cfg: RAG configuration
        split: "main" or "challenge"
        run_name: Experiment name
        generation_file: Path to previously generated answers file (optional)
    """
    if generation_file and os.path.exists(generation_file):
        # Reuse existing generation
        print(f"📂 Loading generations from {generation_file}")
        return run_evaluation(generation_file, run_name)
    else:
        # Full cycle: generation + evaluation
        gen_file = run_generation(cfg, split, run_name)
        return run_evaluation(gen_file, run_name)

# %% [markdown]
# ## Task 0: Реализация Baseline Pipeline (4 балла)
#
# Ваша первая задача — реализовать функцию `build_rag_pipeline`. На данном этапе требуется собрать простую архитектуру Dense Retrieval.
#
# **Требования к реализации:**
# 1.  Инициализация моделей через `Settings` (используйте `get_embedder` и `get_llm`).
# 2.  Подключение к `QdrantVectorStore`.
# 3.  Логика индексации: Если коллекция не существует (или `recreate_collection=True`), создать её из `df_corpus`, используя `SentenceSplitter`. Если существует — загрузить существующий индекс.
# 4.  Возврат объектов `index`, `retriever` и `query_engine`.
#
# Обратите внимание на параметр `overfetch_k` в конфиге. Ретривер должен извлекать именно это количество кандидатов.

# %%
def build_rag_pipeline(cfg: RAGConfig, df_corpus: pd.DataFrame, load_llm: bool = True):
    # 1. Setup Models
    Settings.embed_model = get_embedder(cfg.embedding)
    if load_llm: Settings.llm = get_llm(cfg.llm)

    # 2. Vector Store Setup (TODO)
    client = QdrantClient(path=QDRANT_PATH)
    if cfg.recreate_collection and client.collection_exists(collection_name=cfg.qdrant_collection):
        client.delete_collection(collection_name=cfg.qdrant_collection)

    vector_store = QdrantVectorStore(collection_name=cfg.qdrant_collection,
                                     client=client,
                                     )
    storage_context = StorageContext.from_defaults(
          vector_store=vector_store
    )
    # <YOUR CODE HERE>

    # 3. Indexing Logic (TODO)
    # Check if collection exists.
    # If yes & not recreate -> load index.
    if client.collection_exists(cfg.qdrant_collection) and cfg.recreate_collection == False:
        index = VectorStoreIndex.from_vector_store(vector_store, storage_context=storage_context)
    # Else -> create documents, setup splitter, build index.
    else:
        splitter = SentenceSplitter(chunk_size=cfg.chunking.chunk_size, chunk_overlap=cfg.chunking.chunk_overlap)

        documents = [Document(text=row['text'], metadata={"doc_id": str(row['doc_id'])}) for _, row in df_corpus.iterrows()]

        index = VectorStoreIndex.from_documents(documents,
                                                transformations=[splitter],
                                                storage_context=storage_context,
                                                show_progress=True,)

    # <YOUR CODE HERE>

    # 4. Retrieval Construction (TODO)
    retriever = index.as_retriever(similarity_top_k=cfg.retrieval.top_k)# (use cfg.retrieval.overfetch_k)
    query_engine = index.as_query_engine(retriever=retriever) if load_llm else None
    # <YOUR CODE HERE>

    return index, retriever, query_engine, client

# %%
# %%time

# TEST YOUR BASELINE
baseline_cfg = RAGConfig(
    name="baseline",
    chunking=ChunkingConfig(chunk_size=512, chunk_overlap=50),
    retrieval=RetrievalConfig(top_k=5, overfetch_k=15),
    qdrant_collection="scifact_base_512"
)

print("Running Baseline...")
# 1. Run Retrieval
# TODO: Uncomment after implementing pipeline
run_retrieval(baseline_cfg, "main", "baseline")

# 2. Check Results
show_leaderboard("retrieval", "main")
# Out:
# Running Baseline...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# Parsing nodes:   0%|          | 0/5183 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/llama_index/vector_stores/qdrant/base.py:852: UserWarning: Payload indexes have no effect in the local Qdrant. Please use server Qdrant if you need payload indexes.
#   self._client.create_payload_index(
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/1418 [00:00<?, ?it/s]
# Retr baseline:   0%|          | 0/200 [00:00<?, ?it/s]
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#    run_name    ndcg@k  recall@k  ref_free_mean_score  ref_free_redundancy  \
# 0  baseline  0.679419     0.757             0.576636                  0.0
#
#    latency_s
# 0  20.225371
# Embeddings have been explicitly disabled. Using MockEmbedding.
#
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#    run_name    ndcg@k  recall@k  ref_free_mean_score  ref_free_redundancy  \
# 0  baseline  0.679419     0.757             0.576636                  0.0
#
#    latency_s
# 0  20.225371
# CPU times: user 13min 29s, sys: 2min 27s, total: 15min 56s
# Wall time: 16min 43s

# %% [markdown]
# ## Task 1: Chunking Strategies (2 балла)
#
# Размер контекста критически влияет на качество поиска.
#
# **Задание:**
# 1.  **Small vs Large:** Создайте конфигурации для `chunk_size=256` и `chunk_size=1024`. Запустите эксперименты. *Напоминание: при изменении чанкинга необходимо менять имя коллекции или ставить `recreate_collection=True`.*
# 2.  **Hierarchical Chunking:** Реализуйте иерархический чанкинг (`use_hierarchical=True`). Для этого в `build_rag_pipeline` необходимо добавить проверку конфига и использование `HierarchicalNodeParser`. Этот метод индексирует мелкие чанки, но возвращает контекст родительских (крупных) блоков.

# %%
# TODO: Update build_rag_pipeline to support HierarchicalNodeParser

# TODO: Define Configs
# cfg_256 = ...
# cfg_1024 = ...
# cfg_hier = ...

# TODO: Run Experiments
# run_retrieval(cfg_256, "main", "chunk_256")
# show_leaderboard("retrieval", "main")

# %%
from llama_index.core.retrievers import AutoMergingRetriever
from llama_index.core.node_parser import get_leaf_nodes
def build_rag_pipeline(cfg: RAGConfig, df_corpus: pd.DataFrame, load_llm: bool = True):
    # 1. Setup Models
    Settings.embed_model = get_embedder(cfg.embedding)
    if load_llm: Settings.llm = get_llm(cfg.llm)

    # 2. Vector Store Setup (TODO)
    client = QdrantClient(path=QDRANT_PATH)
    if cfg.recreate_collection and client.collection_exists(collection_name=cfg.qdrant_collection):
        client.delete_collection(collection_name=cfg.qdrant_collection)

    vector_store = QdrantVectorStore(collection_name=cfg.qdrant_collection,
                                     client=client,
                                     )
    storage_context = StorageContext.from_defaults(
          vector_store=vector_store
    )
    # <YOUR CODE HERE>

    # 3. Indexing Logic (TODO)
    # Check if collection exists.
    # If yes & not recreate -> load index.
    if client.collection_exists(cfg.qdrant_collection) and cfg.recreate_collection == False:
        index = VectorStoreIndex.from_vector_store(vector_store, storage_context=storage_context)
    # Else -> create documents, setup splitter, build index.
    else:
        documents = [Document(text=row['text'], metadata={"doc_id": str(row['doc_id'])}) for _, row in df_corpus.iterrows()]

        if cfg.chunking.use_hierarchical:

            parser = HierarchicalNodeParser.from_defaults(
                chunk_sizes=[cfg.chunking.chunk_size, cfg.chunking.child_chunk_size],
                chunk_overlap=cfg.chunking.chunk_overlap
            )
            nodes = parser.get_nodes_from_documents(documents)

            storage_context.docstore.add_documents(nodes)

            leaf_nodes = get_leaf_nodes(nodes)
            index = VectorStoreIndex(
                leaf_nodes,
                storage_context=storage_context,
                show_progress=True
            )


        else:
            splitter = SentenceSplitter(chunk_size=cfg.chunking.chunk_size, chunk_overlap=cfg.chunking.chunk_overlap)



            index = VectorStoreIndex.from_documents(documents,
                                                    transformations=[splitter],
                                                    storage_context=storage_context,
                                                    show_progress=True,)

    base_retriever = index.as_retriever(similarity_top_k=cfg.retrieval.top_k)
    retriever = AutoMergingRetriever(base_retriever, storage_context, verbose=True) if cfg.chunking.use_hierarchical else base_retriever
    query_engine = index.as_query_engine(retriever=retriever) if load_llm else None
    # <YOUR CODE HERE>

    return index, retriever, query_engine, client

# %%
cfg_256 = RAGConfig(
    name="chunk_256",
    chunking=ChunkingConfig(chunk_size=256, chunk_overlap=50),
    retrieval=RetrievalConfig(top_k=5, overfetch_k=15),
    qdrant_collection="scifact_base_256",
    recreate_collection=True
)
run_retrieval(cfg_256, "main", "chunk_256")
show_leaderboard("retrieval", "main")
# Out:
# Parsing nodes:   0%|          | 0/5183 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/926 [00:00<?, ?it/s]
# Retr chunk_256:   0%|          | 0/200 [00:00<?, ?it/s]
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#     run_name    ndcg@k  recall@k  ref_free_mean_score  ref_free_redundancy  \
# 0   baseline  0.679419   0.75700             0.576636                  0.0
# 1  chunk_256  0.676258   0.74475             0.595419                  0.0
#
#    latency_s
# 0  20.225371
# 1  25.289667
# Embeddings have been explicitly disabled. Using MockEmbedding.
#
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#     run_name    ndcg@k  recall@k  ref_free_mean_score  ref_free_redundancy  \
# 0   baseline  0.679419   0.75700             0.576636                  0.0
# 1  chunk_256  0.676258   0.74475             0.595419                  0.0
#
#    latency_s
# 0  20.225371
# 1  25.289667

# %%
cfg_1024 = RAGConfig(
    name="chunk_1024",
    chunking=ChunkingConfig(chunk_size=1024, chunk_overlap=50),
    retrieval=RetrievalConfig(top_k=5, overfetch_k=15),
    qdrant_collection="scifact_base_1024",
    recreate_collection=True
)
run_retrieval(cfg_1024, "main", "chunk_1024")
show_leaderboard("retrieval", "main")
# Out:
# Parsing nodes:   0%|          | 0/5183 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/1099 [00:00<?, ?it/s]
# Retr chunk_1024:   0%|          | 0/200 [00:00<?, ?it/s]
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#      run_name    ndcg@k  recall@k  ref_free_mean_score  ref_free_redundancy  \
# 2  chunk_1024  0.686555   0.76450             0.571906                  0.0
# 0    baseline  0.679419   0.75700             0.576636                  0.0
# 1   chunk_256  0.676258   0.74475             0.595419                  0.0
#
#    latency_s
# 2  20.016812
# 0  20.225371
# 1  25.289667
# Embeddings have been explicitly disabled. Using MockEmbedding.
#
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#      run_name    ndcg@k  recall@k  ref_free_mean_score  ref_free_redundancy  \
# 2  chunk_1024  0.686555   0.76450             0.571906                  0.0
# 0    baseline  0.679419   0.75700             0.576636                  0.0
# 1   chunk_256  0.676258   0.74475             0.595419                  0.0
#
#    latency_s
# 2  20.016812
# 0  20.225371
# 1  25.289667

# %%
cfg_hier = RAGConfig(
    name="hier",
    chunking=ChunkingConfig(chunk_size=512, chunk_overlap=50, use_hierarchical=True, child_chunk_size=128),
    retrieval=RetrievalConfig(top_k=5, overfetch_k=15),
    qdrant_collection="scifact_hier",
    recreate_collection=True

)
run_retrieval(cfg_hier, "main", "hier")
show_leaderboard("retrieval", "main")
# Out:
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/qdrant_client/qdrant_client.py:1868: UserWarning: Local mode is not recommended for collections with more than 20,000 points. Current collection contains 20480 points. Consider using Qdrant in Docker or Qdrant Cloud for better performance with large datasets.
#   return self._client.upload_points(
# Generating embeddings:   0%|          | 0/557 [00:00<?, ?it/s]
# Retr hier:   0%|          | 0/200 [00:00<?, ?it/s]
# > Merging 5 nodes into parent node.
# > Parent node id: a2ca7067-abff-4d9d-abfb-1f001caadb2c.
# > Parent node text: OBJECTIVES To carry out a further survey of archived appendix samples to understand better the di...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0554f05e-0bc1-4098-85d2-d9f99281b912.
# > Parent node text: CONCLUSION Public health interventions directed at reducing neonatal death should address communi...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 2faec013-856a-4181-8281-fcbc3fa44ffd.
# > Parent node text: BACKGROUND The heritable haemoglobinopathy alpha(+)-thalassaemia is caused by the reduced synthes...
#
# > Merging 3 nodes into parent node.
# > Parent node id: c33fd353-8f25-4bf6-a498-e9638f0356ac.
# > Parent node text: Adenosine deaminases acting on RNA (ADARs) are involved in RNA editing that converts adenosine re...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 1ef13101-031a-411d-abc1-8ae5f6b41c87.
# > Parent node text: Expression of the intermediate filament protein keratin 17 (K17) is robustly upregulated in infla...
#
# > Merging 3 nodes into parent node.
# > Parent node id: ef5726c7-b4dd-4cbd-bc25-11e761a5fb1c.
# > Parent node text: Application of stem cell biology to breast cancer research has been limited by the lack of simple...
#
# > Merging 4 nodes into parent node.
# > Parent node id: c566a99d-311c-4a39-b692-d4ea18df0bd0.
# > Parent node text: Fibrosis is a pathological result of a dysfunctional repair response to tissue injury and occurs ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 5694407e-b439-45bc-ae11-4bab001c35d6.
# > Parent node text: Efforts to develop drugs for Alzheimer's disease (AD) have shown promise in animal studies, only ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 5694407e-b439-45bc-ae11-4bab001c35d6.
# > Parent node text: Efforts to develop drugs for Alzheimer's disease (AD) have shown promise in animal studies, only ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: ba984edf-3fbf-4760-afa4-0ec0ff2431bd.
# > Parent node text: Stem cells are proposed to segregate chromosomes asymmetrically during self-renewing divisions so...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 52cbe3dd-d293-4f09-9f47-08c368712026.
# > Parent node text: Angiotensin converting enzyme (ACE) inhibitors are now one of the most frequently used classes of...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 4b885980-b3a8-4fc0-a244-12eb7cf998db.
# > Parent node text: Plus-end tracking proteins, such as EB1 and the dynein/dynactin complex, regulate microtubule dyn...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 5dd8dd6d-789d-4595-93df-a92b7b12edaf.
# > Parent node text: In patients presenting with idiopathic pulmonary fibrosis (IPF), modifications of pulmonary vesse...
#
# > Merging 2 nodes into parent node.
# > Parent node id: bfa8462b-5c4e-40ad-8bdc-0814a9b2fd64.
# > Parent node text: Macrophages produce a large amount of PGE(2) during inflammation. This lipid mediator modulates v...
#
# > Merging 4 nodes into parent node.
# > Parent node id: c99d4a2c-b5cb-4d24-ab48-1a8c2891bd0a.
# > Parent node text: OBJECTIVE To assess whether population screening for impaired vision among older people in the co...
#
# > Merging 4 nodes into parent node.
# > Parent node id: f39d1958-3067-4619-a85f-a7d8a37238b0.
# > Parent node text: CONTEXT Antibody-based induction therapy plus calcineurin inhibitors (CNIs) reduce acute rejectio...
#
# > Merging 4 nodes into parent node.
# > Parent node id: f39d1958-3067-4619-a85f-a7d8a37238b0.
# > Parent node text: CONTEXT Antibody-based induction therapy plus calcineurin inhibitors (CNIs) reduce acute rejectio...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 90ba2f8c-c779-403b-bc37-0b040f10aa35.
# > Parent node text: In systemic lupus erythematosus (SLE), self-reactive antibodies can target the kidney (lupus neph...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 2787f06c-9d96-43c3-b53d-807997139809.
# > Parent node text: Breast cancer may originate in utero. We reviewed the available evidence on the association betwe...
#
# > Merging 2 nodes into parent node.
# > Parent node id: ed475ec9-9028-4ae8-87b6-ca504f1b8cbb.
# > Parent node text: Genetic mutations in TAR DNA-binding protein 43 (TARDBP, also known as TDP-43) cause amyotrophic ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: ac3e6c51-8f2c-4640-9aec-7a1c988c466d.
# > Parent node text: Mononuclear phagocytes, including monocytes, macrophages, and dendritic cells, contribute to tiss...
#
# > Merging 2 nodes into parent node.
# > Parent node id: d410320d-7ee4-4080-ba2a-7a41a6469150.
# > Parent node text: Allergic asthma is a T helper type 2 (T(H)2)-dominated disease of the lung. In people with asthma...
#
# > Merging 3 nodes into parent node.
# > Parent node id: d410320d-7ee4-4080-ba2a-7a41a6469150.
# > Parent node text: Allergic asthma is a T helper type 2 (T(H)2)-dominated disease of the lung. In people with asthma...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 360cdeb7-86a4-4fdd-be04-c51654737172.
# > Parent node text: CONCLUSIONS Trachoma is an unnecessary public health problem in Ayod. The high prevalence of acti...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 94f11f41-341d-45b5-8251-5bb4126e93fd.
# > Parent node text: Background Blindness and low vision are thought to be common in southern Sudan. However, the magn...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 46c153cb-012c-4cbc-b146-11d566f88c47.
# > Parent node text: In the mammalian model of sex determination, embryos are considered to be sexually indifferent un...
#
# > Merging 3 nodes into parent node.
# > Parent node id: a3ea4265-4b0a-4048-a09a-6a47b711d4a0.
# > Parent node text: Clp-controlled proteolysis in Bacillus subtilis seems to play a substantial role, particularly un...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 7e9d8afb-a9e6-48f9-be32-84288c3d3ca2.
# > Parent node text: Aging is characterized by a progressive loss of physiological integrity, leading to impaired func...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 8a327e8c-1770-4538-8fff-3cc82eca392a.
# > Parent node text: The interest in brown adipose tissue (BAT) as a target to combat metabolic disease has recently b...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c5b9cab8-33d7-44f4-90cd-bcf50b3fe7dc.
# > Parent node text: There was a significant negative correlation between plasma NOx concentration and plasma ET-1 con...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 6c708192-922c-4540-8b39-e9419cdcddc0.
# > Parent node text: At 52 weeks, 30.9% of the combination therapy group achieved prolonged and 36.6% achieved 7-day p...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 9dd93dc8-152e-4067-b09c-288c18a947f5.
# > Parent node text: IMPORTANCE Combining pharmacotherapies for tobacco-dependence treatment may increase smoking abst...
#
# > Merging 2 nodes into parent node.
# > Parent node id: c5d74c10-58a3-4d7c-9c40-13d051f20edd.
# > Parent node text: Sri Lankan black pepper with symptoms of yellow mottle disease contained a mixture of viruses: Pi...
#
# > Merging 2 nodes into parent node.
# > Parent node id: cd3850c5-0db2-420b-908a-9516ecd50fbf.
# > Parent node text: Mice lacking the transcription factor T-bet in the innate immune system develop microbiota-depend...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 5e56f4d6-722e-4929-99c2-47bfac4edabb.
# > Parent node text: Results of experimental and genetic studies have highlighted the role of the IL-23/IL-17 axis in ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: ce824592-aeb7-4434-9638-bbafe465e982.
# > Parent node text: Tight regulation of the expression of mRNAs encoding iron uptake proteins is essential to control...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 25046109-78d7-4c2f-ac71-87bcfbfd52e4.
# > Parent node text: Massively parallel sequencing of cDNA has enabled deep and efficient probing of transcriptomes. C...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 5f0e1336-af3c-400b-866d-c332da1a4972.
# > Parent node text: Loss of cell polarity proteins such as Scribble induces neoplasia in Drosophila by promoting unco...
#
# > Merging 2 nodes into parent node.
# > Parent node id: a1978231-9c2d-44e6-94ea-57ca376f46a5.
# > Parent node text: Epigenetic silencing of immune-related genes is a striking feature of the cancer genome that occu...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 712ac78a-6c3c-4b7c-b1ba-0d1c07fd361a.
# > Parent node text: OBJECTIVES To determine the incidence and clinical importance of errors in the preparation and ad...
#
# > Merging 5 nodes into parent node.
# > Parent node id: 545d82d2-1a75-4712-885e-ddeb0a774991.
# > Parent node text: OBJECTIVE To determine whether higher past exposure to particulate air pollution is associated wi...
#
# > Merging 2 nodes into parent node.
# > Parent node id: b08818fb-dfb4-476b-b204-024b1ce1fa82.
# > Parent node text: Febrile (fever-induced) seizures affect 3–5% of infants and young children. Despite the high inci...
#
# > Merging 2 nodes into parent node.
# > Parent node id: b08818fb-dfb4-476b-b204-024b1ce1fa82.
# > Parent node text: Febrile (fever-induced) seizures affect 3–5% of infants and young children. Despite the high inci...
#
# > Merging 2 nodes into parent node.
# > Parent node id: f845bde2-8d2b-4261-84f8-036d3ef9a359.
# > Parent node text: Reactive oxygen species (ROS) are potentially harmful to cells because of their ability to oxidiz...
#
# > Merging 3 nodes into parent node.
# > Parent node id: d35c7ab0-7127-43cf-be53-11cd12fdbb08.
# > Parent node text: Environmental and genetic aberrations lead to neural tube closure defects (NTDs) in 1 out of ever...
#
# > Merging 2 nodes into parent node.
# > Parent node id: f42a82c4-58e7-4be2-9864-041480bde34f.
# > Parent node text: Maintaining hematopoietic stem cell (HSC) quiescence is a critical property for the life-long gen...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 20fc82af-256a-424c-8637-63712cc2a828.
# > Parent node text: The physiologic roles of angiopoietin-like proteins (Angptls) in the hematopoietic system remain ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 1cd492aa-eb7d-4955-b00a-3933164a97c5.
# > Parent node text: Proper execution of transcriptional programs is a key requirement of gene expression regulation, ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 18cdefc9-d67f-4e38-953b-81bcc2fb3b51.
# > Parent node text: Gene expression is a fundamentally stochastic process, with randomness in transcription and trans...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 90253e96-250c-4538-84e6-9a8917a9f68e.
# > Parent node text: Mammalian cells depend on growth factor signaling to take up nutrients; however, coordination of ...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 052d586a-a8fd-4452-9b5b-95fbbe8101aa.
# > Parent node text: Tuberculosis and helminthic infections coexist in many parts of the world, yet the impact of helm...
#
# > Merging 2 nodes into parent node.
# > Parent node id: de12a690-4f53-4419-bd8c-f50099701534.
# > Parent node text: If the 3-5 ng/L cut-off value is used, <1 (0 to 1) patient with acute myocardial infarction will ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 9877cb6f-508c-482c-a407-06045a68ca63.
# > Parent node text: Nuclear receptors undergo ligand-dependent conformational changes that are required for corepress...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 7b75f453-737c-41d5-9c89-e572161b70d3.
# > Parent node text: The attributable risk of dementia between individuals with and without a history of hypoglycemia ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 9d072c6f-e455-4d49-a31b-b7d72b83032e.
# > Parent node text: BACKGROUND Exosomes are extracellular vesicles that mediate cellular communication in health and ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: c3977241-dad2-4172-be2a-56f937ecb8ca.
# > Parent node text: Duplication and segregation of chromosomes involves dynamic reorganization of their internal stru...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 95cdf668-2155-4029-92e8-c5d552673f89.
# > Parent node text: Leukemias and other cancers possess self-renewing stem cells that help to maintain the cancer. Ca...
#
# > Merging 4 nodes into parent node.
# > Parent node id: dd6f8115-4e2f-440c-9eb1-dd0c79b1a304.
# > Parent node text: Fucci technology makes possible the distinction between live cells in the G(1) and S/G(2)/M phase...
#
# > Merging 4 nodes into parent node.
# > Parent node id: b3e4fc45-fd1a-4a4d-afe7-d53af94f4942.
# > Parent node text: CONTEXT More than 1.5 million US adults use stimulants and other medications labeled for treatmen...
#
# > Merging 4 nodes into parent node.
# > Parent node id: fc412389-6de5-4efe-abc7-a889bb29d508.
# > Parent node text: OBJECTIVE To describe the efficacy of the Finnish mass screening program for cervical squamous ca...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 7d58d3bf-e22c-46f1-88dd-c9124d2bfe07.
# > Parent node text: Leucine-rich repeat kinase 2 (LRRK2) mutations are the most common genetic cause of Parkinson's d...
#
# > Merging 2 nodes into parent node.
# > Parent node id: a272d2a4-e9be-4b52-bbe9-6de8f32b4dde.
# > Parent node text: Multiple sclerosis (MS) shows a multifold increase in prevalence with an increase in latitudes, b...
#
# > Merging 2 nodes into parent node.
# > Parent node id: d02c2254-9f03-4939-966e-2ba68e4bbe58.
# > Parent node text: OBJECTIVE To examine whether past high sun exposure is associated with a reduced risk of multiple...
#
# > Merging 5 nodes into parent node.
# > Parent node id: 1569dea9-ffba-40f1-994f-a3522bfcb134.
# > Parent node text: CONTEXT Insomnia is a common condition in older adults and is associated with a number of adverse...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 0c73e6dd-8e64-412c-9983-7a9b48d39a9f.
# > Parent node text: Soluble factors from serum such as lysophosphatidic acid (LPA) are thought to activate the small ...
#
# > Merging 5 nodes into parent node.
# > Parent node id: 8f20b317-a382-4300-bc37-1cc793c0ac01.
# > Parent node text: CONTEXT A number of countries have implemented a policy of universal leukoreduction of their bloo...
#
# > Merging 5 nodes into parent node.
# > Parent node id: 8f20b317-a382-4300-bc37-1cc793c0ac01.
# > Parent node text: CONTEXT A number of countries have implemented a policy of universal leukoreduction of their bloo...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 5e3dc2e5-ffbe-4d89-a899-5522bda1938f.
# > Parent node text: Dynamically polarized membrane proteins define different cell boundaries and have an important ro...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 18695023-fa68-429e-a200-d8ba5f5d8098.
# > Parent node text: MicroRNAs (miRNAs) are a family of short, non-coding RNA molecules (∼22nt) involved in post-trans...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 2a2c0923-ab5c-44fd-b1db-bf56f31e6491.
# > Parent node text: Dnmt1 epigenetically propagates symmetrical CG methylation in many eukaryotes. Their genomes are ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8365b0e9-b37d-40c3-879d-1c3fe5450750.
# > Parent node text: Our finding that chromatin structure is irrelevant for repression as studied here-that is, repres...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 3315e4c8-8425-4d3b-924e-7a8d3fd29782.
# > Parent node text: Neutrophils rapidly undergo polarization and directional movement to infiltrate the sites of infe...
#
# > Merging 3 nodes into parent node.
# > Parent node id: bde03915-3a8d-4db5-aaf1-70507dc429de.
# > Parent node text: Blood monocytes are well-characterized precursors for macrophages and dendritic cells. Subsets of...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 5bf46186-e6e1-464c-bea6-aeb11e9a441c.
# > Parent node text: We generated a series of knockin mouse lines, in which the cytokine receptor gp130-dependent STAT...
#
# > Merging 2 nodes into parent node.
# > Parent node id: e453a40a-6e99-4514-8cac-5b7ef7611230.
# > Parent node text: Macropinocytosis is a regulated form of endocytosis that mediates the non-selective uptake of sol...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 994a75df-f512-46cf-8a40-25adf97e4b53.
# > Parent node text: Macropinocytosis is a highly conserved endocytic process by which extracellular fluid and its con...
#
# > Merging 2 nodes into parent node.
# > Parent node id: f95a62b9-e6ca-4a40-9657-216f0de96e7a.
# > Parent node text: Lysine acetylation is a reversible posttranslational modifcation, an epigenetic phenomenon, refer...
#
# > Merging 2 nodes into parent node.
# > Parent node id: f5b2b21d-c6e6-4c4b-861b-01c5adca2753.
# > Parent node text: Lysine acetylation is a conserved protein post-translational modification that links acetyl-coenz...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 89cc9f85-e19a-4221-8691-51b0d60c7bb5.
# > Parent node text: The risk of having any grade 3 or worse toxic effect was not significantly increased with oxalipl...
#
# > Merging 2 nodes into parent node.
# > Parent node id: dde75b73-449d-48cf-9f69-ddee4ad5a6d9.
# > Parent node text: DNA polymerase β (Pol β) is an error-prone enzyme which has been found to be overexpressed in sev...
#
# > Merging 3 nodes into parent node.
# > Parent node id: b4a0f3bc-423f-49c2-b779-c3237f1485fb.
# > Parent node text: BACKGROUND Interleukin (IL)-12 exerts a potent proinflammatory effect by stimulating T-helper (Th...
#
# > Merging 3 nodes into parent node.
# > Parent node id: af4ed6f3-41f4-40a6-8f02-a1fba6225b2e.
# > Parent node text: Methyl-CpG binding protein 1 (MBD1) regulates gene expression via a DNA methylation-mediated epig...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 71ae1794-2902-4f55-b619-c7451b8717ab.
# > Parent node text: In this review I summarize interrelations between bioenergetic processes and such programmed deat...
#
# > Merging 2 nodes into parent node.
# > Parent node id: e3ec389d-e33d-4eb7-aab0-6ebd0e652394.
# > Parent node text: The exploration of brain epigenomes, which consist of various types of DNA methylation and covale...
#
# > Merging 4 nodes into parent node.
# > Parent node id: a2c4a134-8509-40eb-a94c-f7929c9f124d.
# > Parent node text: The transition from androgen-dependent to castration-resistant prostate cancer (CRPC) is a lethal...
#
# > Merging 4 nodes into parent node.
# > Parent node id: aa57cf59-cd3a-4f5a-af0c-05ddde1c76f1.
# > Parent node text: Activating mutations in genes encoding G protein α (Gα) subunits occur in 4-5% of all human cance...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 6efe1857-ce41-4e9f-b2e6-6937d16e8826.
# > Parent node text: The appearance of N348I was associated with a significant increase in viral load (p , 0.001), whi...
#
# > Merging 4 nodes into parent node.
# > Parent node id: cd2fa721-68a1-43f6-a721-7819682897c8.
# > Parent node text: Successful pregnancy requires coordination of an array of signals and factors from multiple tissu...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 4f3fe861-4693-45a0-93bd-19eed7e2f666.
# > Parent node text: Currently, major concerns about the safety and efficacy of RNA interference (RNAi)-based bone ana...
#
# > Merging 2 nodes into parent node.
# > Parent node id: a81eac5a-0520-4b8a-984a-5d6b092e19a6.
# > Parent node text: Antigen targeting and adjuvancy schemes that respectively facilitate delivery of antigen to dendr...
#
# > Merging 1 nodes into parent node.
# > Parent node id: a256e325-2359-433a-9b2b-d4cf0e843bab.
# > Parent node text: Neutrophil extracellular traps (NETs) are made of processed chromatin bound to granular and selec...
#
# > Merging 2 nodes into parent node.
# > Parent node id: a66c6071-53c3-4ea4-9491-49ac76ce11f6.
# > Parent node text: The TLX1 and TLX3 transcription factor oncogenes have a key role in the pathogenesis of T cell ac...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 121f9d99-9ab9-4c5f-b3da-0136ff6818df.
# > Parent node text: The lncRNA H19 has been recently shown to be upregulated and play important roles in gastric canc...
#
# > Merging 2 nodes into parent node.
# > Parent node id: ea280b0d-605c-4b2f-adfe-5d7943761f3b.
# > Parent node text: We examined the contributions of genetic factors and the family environment to human fatness in a...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 527694c3-d892-4307-8752-a775213ea2bc.
# > Parent node text: An analysis of the genetic factors in obesity has been carried out on a sample of nuclear familie...
#
# > Merging 3 nodes into parent node.
# > Parent node id: e6cbc549-34f8-45e9-ba0a-4ada05a2a7ee.
# > Parent node text: Large noncoding RNAs are emerging as an important component in cellular regulation. Considerable ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: e6cbc549-34f8-45e9-ba0a-4ada05a2a7ee.
# > Parent node text: Large noncoding RNAs are emerging as an important component in cellular regulation. Considerable ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 9ab334e4-f7d3-4c51-be01-da63023cc802.
# > Parent node text: Viral replication and microbial translocation from the gut to the blood during HIV infection lead...
#
# > Merging 2 nodes into parent node.
# > Parent node id: f6cfb06b-c1c0-4860-95b5-9557184ac5a0.
# > Parent node text: Chronic immune activation that persists despite anti-retroviral therapy (ART) is the strongest pr...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 95493b87-14e3-4f41-94fc-098ffd125682.
# > Parent node text: To initiate adaptive immunity, dendritic cells (DCs) move from parenchymal tissues to lymphoid or...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 156d2cd0-9cbf-409d-b571-29395f5b88dd.
# > Parent node text: Although aberrant DNA methylation is considered to be one of the key ways by which tumor-suppress...
#
# > Merging 3 nodes into parent node.
# > Parent node id: c4f6d3f1-765a-4697-94e1-269862b3fd95.
# > Parent node text: Liver X receptors (LXR) are oxysterol-activated nuclear receptors that play a central role in rev...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 3509bac3-dd7f-47c1-bdc2-44f2eb314da3.
# > Parent node text: CONCLUSIONS In this study of adults with subjective memory impairment, a 6-month program of physi...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 049e0927-9a8f-47e3-ad5d-20419d297f45.
# > Parent node text: OBJECTIVES To explore the association between a stable partnership and clinical outcome in HIV in...
#
# > Merging 3 nodes into parent node.
# > Parent node id: d63a0dc2-a218-4b38-b14a-7520098add55.
# > Parent node text: Antigen-specific CD8+ T-cell tolerance, induced by myeloid-derived suppressor cells (MDSCs), is o...
#
# > Merging 4 nodes into parent node.
# > Parent node id: dc8581ba-9e3a-4929-b9d8-ffeeb742b830.
# > Parent node text: OBJECTIVE Although the Polypill concept (proposed in 2003) is promising in terms of benefits for ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 807a1026-a70c-4a29-8c0b-3673814a776d.
# > Parent node text: Local translation mediates axonal responses to Semaphorin3A (Sema3A) and other guidance cues. How...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 0d3571ad-a195-4e30-a4ee-65a9145bacfd.
# > Parent node text: Although susceptibility of neurons in the brain to microbial infection is a major determinant of ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 59a083d1-ef66-4049-82d7-86fdfe79e9f0.
# > Parent node text: Studies with mice lacking the common plasma membrane receptor for type I interferon (IFN-αβR(-)(/...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 0d3571ad-a195-4e30-a4ee-65a9145bacfd.
# > Parent node text: Although susceptibility of neurons in the brain to microbial infection is a major determinant of ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 59a083d1-ef66-4049-82d7-86fdfe79e9f0.
# > Parent node text: Studies with mice lacking the common plasma membrane receptor for type I interferon (IFN-αβR(-)(/...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 5f01be03-0059-44ab-87b8-a89198c980ce.
# > Parent node text: Autoimmune diseases are thought to result from imbalances in normal immune physiology and regulat...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 3abd53bd-f4c9-446a-9f49-5bcd1dac4f69.
# > Parent node text: H2A.Z is an evolutionary conserved histone variant involved in transcriptional regulation, antisi...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 83ac5cfe-974d-4e84-bb59-ee856d565dd5.
# > Parent node text: Ribosome biogenesis and protein synthesis are two of the most energy consuming processes in a gro...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 54ad9839-8f03-4955-a7e9-5e76faebb40a.
# > Parent node text: Resistance to apoptosis, often achieved by the overexpression of antiapoptotic proteins, is commo...
#
# > Merging 5 nodes into parent node.
# > Parent node id: bbdefabb-53fb-4c0b-8dd3-0f8315d76f78.
# > Parent node text: Modification of proteins by SUMO is essential for the maintenance of genome integrity. During DNA...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 96d858fc-1eff-4665-a075-26303728ff72.
# > Parent node text: The AORs for current use of statins defined as 20 or more prescriptions were similar (around 0.6)...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 96d858fc-1eff-4665-a075-26303728ff72.
# > Parent node text: The AORs for current use of statins defined as 20 or more prescriptions were similar (around 0.6)...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 27075d7a-a140-4e1b-95d1-582234f4f36d.
# > Parent node text: Conclusions and Relevance Among patients with ICH, prior use of NOACs or warfarin was associated ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: e51063ff-0da2-44fb-9f76-b0c50beb63d8.
# > Parent node text: Brown adipocytes dissipate energy, whereas white adipocytes are an energy storage site. We explor...
#
# > Merging 4 nodes into parent node.
# > Parent node id: f7e480e4-18cf-4171-bbaa-9991e5901684.
# > Parent node text: Brain-derived neurotrophic factor (BDNF) and its receptor TrkB are crucial for many forms of neur...
#
# > Merging 3 nodes into parent node.
# > Parent node id: d1eb2693-1f23-4638-b4ca-5ba6be55b97e.
# > Parent node text: Regulatory T (Treg) cells play a pivotal role in suppressing self-harmful T cell responses, but h...
#
# > Merging 2 nodes into parent node.
# > Parent node id: b4af7c10-bbcd-4daa-9c38-f5afacae8254.
# > Parent node text: Significant endeavor has been applied to identify functional therapeutic targets in glioblastoma ...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 34a6e107-2335-4fc4-ba5f-7d8ec76e5da0.
# > Parent node text: Background  Extensive debate exists in the healthcare community over whether outcomes of medical ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 7f50c539-df14-4ebc-8ed4-d1569cbb97fd.
# > Parent node text: Acute Myelogenous Leukemia (AML) is an aggressive cancer that strikes both adults and children an...
#
# > Merging 2 nodes into parent node.
# > Parent node id: e741d5c8-37e6-413b-8bee-7a4c45071e8f.
# > Parent node text: The YAP transcription coactivator has been implicated as an oncogene and is amplified in human ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 156762f5-fc10-45c8-ae6f-123cfcf99e73.
# > Parent node text: This article reviews and critiques community-based research on the effects of homelessness on chi...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 668cf07d-4bca-445b-8d5d-29c568a06eaf.
# > Parent node text: Governments have shown an interest in early intervention strategies to reduce youth homelessness,...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 9cadbd0d-16d8-4133-ba22-a5698f16e341.
# > Parent node text: Statins are widely used in the evidence-based lowering of cardiovascular disease (CVD) risk. The ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: dfd2c00d-52ed-4ac6-9ee6-496317166bd6.
# > Parent node text: Self-renewal and differentiation of stem cells depend on asymmetric division and polarized motili...
#
# > Merging 3 nodes into parent node.
# > Parent node id: a54441d7-6b25-4481-af74-5b7ca48733ee.
# > Parent node text: The signals and molecular mechanisms that regulate the replication of terminally differentiated b...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 3ceec08d-96cc-4002-8f80-ec0945e2009b.
# > Parent node text: Ten-Eleven Translocation-2 (TET2) inactivation through loss-of-function mutation, deletion and ID...
#
# > Merging 2 nodes into parent node.
# > Parent node id: a79d4ed2-5793-46a2-af70-a91aa473fa52.
# > Parent node text: Arodent cardiac side population cell fraction formed clonal spheroids in serum-free medium, which...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 267d2685-cd6c-4799-b01f-74922072c10f.
# > Parent node text: OBJECTIVES To explore the use of local civil registration data to assess the perinatal mortality ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 7addba83-9775-4830-b944-1e659cc118a1.
# > Parent node text: The RNA-guided DNA endonuclease Cas9 is a powerful tool for genome editing. Little is known about...
#
# > Merging 1 nodes into parent node.
# > Parent node id: de25caad-c784-4fc4-82c3-0b0ee0eb3f2d.
# > Parent node text: INTERPRETATION The burden of self-harm in prisoners is substantial, particularly in women. Self-h...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 64fac113-3432-45a3-b87d-1ba115b98606.
# > Parent node text: BACKGROUND The prognosis and treatment of the 2 main types of cardiac amyloidosis, immunoglobulin...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 860a5d33-e85b-4743-a697-b9c60a290d94.
# > Parent node text: Molecular motors play critical roles in the formation of mitotic spindles, either through control...
#
# > Merging 2 nodes into parent node.
# > Parent node id: f243397f-8f7f-4cda-9634-36b24e54a22d.
# > Parent node text: The mechanisms by which melanoma and other cancer cells evade anti-tumor immunity remain incomple...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 82d611a6-a424-4aa4-a46c-1af02aa9ab33.
# > Parent node text: In vivo activation of Klebsiella aerogenes urease, a nickel-containing enzyme, requires the prese...
#
# > Merging 3 nodes into parent node.
# > Parent node id: ce09d9c3-37a4-45a5-9f4a-6ab080324c06.
# > Parent node text: CONTEXT Recent animal studies have found that 3-hydroxy-3-methylglutaryl coenzyme A (HMG-CoA) lip...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 6ccac895-0f4e-49c7-8adf-fc01064b6d2e.
# > Parent node text: The relationship between statin use and hip fracture risk persisted after controlling for variabl...
#
# > Merging 5 nodes into parent node.
# > Parent node id: 13a91683-50b2-42a4-b556-2bf90c83f2c3.
# > Parent node text: BACKGROUND Deep vein thrombosis (DVT) and pulmonary embolism are common after stroke. In small tr...
#
# > Merging 3 nodes into parent node.
# > Parent node id: eb6595c1-66cf-435c-bb75-06d10d0f5303.
# > Parent node text: Umbilical cord blood (UCB) is now widely used as an alternative hematopoietic stem cell source fo...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 1f813f80-f497-4f95-b290-7c17cba9c3fc.
# > Parent node text: CD4(+) T follicular helper (Tfh) cells provide the required signals to B cells for germinal cente...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 5ec8c03b-2bd0-46e9-9034-8d9d1b3e9588.
# > Parent node text: Human astrocytes are larger and more complex than those of infraprimate mammals, suggesting that ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 098b660a-9077-4f10-a9a3-b90d62d7a115.
# > Parent node text: The increasing understanding of the role of cytokines in autoimmunity, and the observation that t...
#
# > Merging 3 nodes into parent node.
# > Parent node id: eb6595c1-66cf-435c-bb75-06d10d0f5303.
# > Parent node text: Umbilical cord blood (UCB) is now widely used as an alternative hematopoietic stem cell source fo...
#
# > Merging 3 nodes into parent node.
# > Parent node id: eb6595c1-66cf-435c-bb75-06d10d0f5303.
# > Parent node text: Umbilical cord blood (UCB) is now widely used as an alternative hematopoietic stem cell source fo...
#
# > Merging 5 nodes into parent node.
# > Parent node id: 76e0c47d-ad99-4087-ad92-6bffa5a22f9c.
# > Parent node text: OBJECTIVE To determine whether ultrasound imaging can reduce the risk of failed lumbar punctures ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 9dd93dc8-152e-4067-b09c-288c18a947f5.
# > Parent node text: IMPORTANCE Combining pharmacotherapies for tobacco-dependence treatment may increase smoking abst...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 6c708192-922c-4540-8b39-e9419cdcddc0.
# > Parent node text: At 52 weeks, 30.9% of the combination therapy group achieved prolonged and 36.6% achieved 7-day p...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 5dd8dd6d-789d-4595-93df-a92b7b12edaf.
# > Parent node text: In patients presenting with idiopathic pulmonary fibrosis (IPF), modifications of pulmonary vesse...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 5dd8dd6d-789d-4595-93df-a92b7b12edaf.
# > Parent node text: In patients presenting with idiopathic pulmonary fibrosis (IPF), modifications of pulmonary vesse...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 2787f06c-9d96-43c3-b53d-807997139809.
# > Parent node text: Breast cancer may originate in utero. We reviewed the available evidence on the association betwe...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 37f9179b-e3f0-41c1-b207-326362e77ab9.
# > Parent node text: T cell receptor (TCR) signaling is initiated and sustained in microclusters; however, it's not kn...
#
# > Merging 2 nodes into parent node.
# > Parent node id: d925a66b-2f38-4063-bf88-1161e7fbd937.
# > Parent node text: T cell activation is predicated on the interaction between the T cell receptor and peptide-major ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 223cfdc0-0e4c-465f-82ca-a3c804d5c390.
# > Parent node text: Mutations in cancer reprogram amino acid metabolism to drive tumor growth, but the molecular mech...
#
#
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#      run_name    ndcg@k  recall@k  ref_free_mean_score  ref_free_redundancy  \
# 2  chunk_1024  0.686555   0.76450             0.571906                  0.0
# 0    baseline  0.679419   0.75700             0.576636                  0.0
# 3        hier  0.678389   0.73350             0.623626                  0.0
# 1   chunk_256  0.676258   0.74475             0.595419                  0.0
#
#    latency_s
# 2  20.016812
# 0  20.225371
# 3  37.767845
# 1  25.289667
# Embeddings have been explicitly disabled. Using MockEmbedding.
#
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#      run_name    ndcg@k  recall@k  ref_free_mean_score  ref_free_redundancy  \
# 2  chunk_1024  0.686555   0.76450             0.571906                  0.0
# 0    baseline  0.679419   0.75700             0.576636                  0.0
# 3        hier  0.678389   0.73350             0.623626                  0.0
# 1   chunk_256  0.676258   0.74475             0.595419                  0.0
#
#    latency_s
# 2  20.016812
# 0  20.225371
# 3  37.767845
# 1  25.289667

# %% [markdown]
# ## Task 2: Optimization & Advanced Retrieval (3 балла)
#
# В этом блоке мы реализуем продвинутые техники для улучшения качества и эффективности.
#
# ### 2.1 Matryoshka Embeddings (Optimization)
# Модель `Qwen/Qwen3-Embedding` поддерживает **Matryoshka Representation Learning (MRL)**. Это позволяет усекать размерность векторов (например, с 1024 до 512) с минимальной потерей качества, что экономит память и ускоряет поиск.
# **Задание:** Измените `truncate_dim` в `EmbeddingConfig` (например, на 512) и проверьте влияние на метрики.
#
# ### 2.2 Advanced Retrieval (Hybrid + Rerank)
# Вам необходимо модифицировать `build_rag_pipeline` (или создать `build_advanced_pipeline`), добавив следующую логику:
# 1.  **Hybrid Search:** Если `cfg.retrieval.mode == 'hybrid'`, создайте `BM25Retriever` и объедините его с векторным через `QueryFusionRetriever` (алгоритм Reciprocal Rank Fusion).
# 2.  **Reranking:** Если `cfg.retrieval.use_reranker == True`, добавьте `SentenceTransformerRerank` в список `node_postprocessors` для `QueryEngine`. Реренкер должен принимать на вход топ-K кандидатов из этапа 1 (`overfetch_k`) и оставлять лучшие N (`rerank_top_n`).
#
# **Concept:** Funnel Architecture (Broad Search -> Narrow Filtering).

# %%
# TODO: Upgrade Pipeline Logic (Hybrid, Reranker)
# def build_rag_pipeline(...):
#     ...

# TODO: Run Experiments
# cfg_matryoshka = ...
# cfg_hybrid_rerank = ...
# run_retrieval(cfg_hybrid_rerank, "main", "advanced_full")
# show_leaderboard("retrieval", "main")

# %%
os.environ["OPENAI_API_KEY"] = '1'

# %%
# df = df_corpus[:10]

# %%
from llama_index.core.postprocessor import SentenceTransformerRerank
def build_rag_pipeline(cfg: RAGConfig, df_corpus: pd.DataFrame, load_llm: bool = True):
    # 1. Setup Models
    Settings.embed_model = get_embedder(cfg.embedding)
    Settings.llm = get_llm(cfg.llm) if load_llm else None

    # 2. Vector Store Setup (TODO)
    client = QdrantClient(path=QDRANT_PATH)
    if cfg.recreate_collection and client.collection_exists(collection_name=cfg.qdrant_collection):
        client.delete_collection(collection_name=cfg.qdrant_collection)

    vector_store = QdrantVectorStore(collection_name=cfg.qdrant_collection,
                                     client=client,
                                     )
    storage_context = StorageContext.from_defaults(
          vector_store=vector_store
    )
    # <YOUR CODE HERE>
    documents = [Document(text=row['text'], metadata={"doc_id": str(row['doc_id'])}) for _, row in df_corpus.iterrows()]
    # 3. Indexing Logic (TODO)
    # Check if collection exists.
    # If yes & not recreate -> load index.
    if client.collection_exists(cfg.qdrant_collection) and cfg.recreate_collection == False:
        index = VectorStoreIndex.from_vector_store(vector_store, storage_context=storage_context)
    # Else -> create documents, setup splitter, build index.
    else:

        if cfg.chunking.use_hierarchical:

            parser = HierarchicalNodeParser.from_defaults(
                chunk_sizes=[cfg.chunking.chunk_size, cfg.chunking.child_chunk_size],
                chunk_overlap=cfg.chunking.chunk_overlap
            )
            nodes = parser.get_nodes_from_documents(documents)

            storage_context.docstore.add_documents(nodes)

            leaf_nodes = get_leaf_nodes(nodes)
            index = VectorStoreIndex(
                leaf_nodes,
                storage_context=storage_context,
                show_progress=True
            )


        else:
            splitter = SentenceSplitter(chunk_size=cfg.chunking.chunk_size, chunk_overlap=cfg.chunking.chunk_overlap)

            nodes = splitter.get_nodes_from_documents(documents)

            index = VectorStoreIndex.from_documents(documents,
                                                    transformations=[splitter],
                                                    storage_context=storage_context,
                                                    show_progress=True,)

    similarity_top_k = cfg.retrieval.overfetch_k if cfg.retrieval.use_reranker else cfg.retrieval.top_k

    base_retriever = index.as_retriever(similarity_top_k=similarity_top_k)
    retriever = AutoMergingRetriever(base_retriever, storage_context, verbose=True) if cfg.chunking.use_hierarchical else base_retriever

    retriever = QueryFusionRetriever([retriever, BM25Retriever.from_defaults(nodes=nodes, similarity_top_k=similarity_top_k)],
                                    similarity_top_k=similarity_top_k, mode="reciprocal_rerank", num_queries=1, use_async=False,) if cfg.retrieval.mode == 'hybrid' else retriever

    # 4. Retrieval Construction (TODO)
    query_engine = None
    if load_llm:
        if cfg.retrieval.use_reranker == True:
            rerank = SentenceTransformerRerank(
                    model=cfg.rerank_model, top_n=cfg.retrieval.rerank_top_n
            )
            query_engine = index.as_query_engine(retriever=retriever, node_postprocessors=[rerank])
        else:
            query_engine = index.as_query_engine(retriever=retriever)


    return index, retriever, query_engine, client

# %%
cfg_matryoshka = RAGConfig(
    name="matryoshka",
    chunking=ChunkingConfig(chunk_size=256, chunk_overlap=50),
    retrieval=RetrievalConfig(top_k=5, overfetch_k=15),
    embedding=EmbeddingConfig(truncate_dim=512),
    qdrant_collection="scifact_matryoshka",
    recreate_collection=True
)
run_retrieval(cfg_matryoshka, "main", "matryoshka")
show_leaderboard("retrieval", "main")
# Out:
# LLM is explicitly disabled. Using MockLLM.
# /tmp/ipython-input-1409258979.py:8: UserWarning: Local mode is not recommended for collections with more than 20,000 points. Collection <scifact_hier> contains 21037 points. Consider using Qdrant in Docker or Qdrant Cloud for better performance with large datasets.
#   client = QdrantClient(path=QDRANT_PATH)
# Parsing nodes:   0%|          | 0/5183 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/926 [00:00<?, ?it/s]
# Retr matryoshka:   0%|          | 0/200 [00:00<?, ?it/s]
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#      run_name    ndcg@k  recall@k  ref_free_mean_score  ref_free_redundancy  \
# 2  chunk_1024  0.686555   0.76450             0.571906                  0.0
# 0    baseline  0.679419   0.75700             0.576636                  0.0
# 3        hier  0.678389   0.73350             0.623626                  0.0
# 1   chunk_256  0.676258   0.74475             0.595419                  0.0
# 4  matryoshka  0.647753   0.72100             0.627007                  0.0
#
#    latency_s
# 2  20.016812
# 0  20.225371
# 3  37.767845
# 1  25.289667
# 4  18.127856
# Embeddings have been explicitly disabled. Using MockEmbedding.
#
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#      run_name    ndcg@k  recall@k  ref_free_mean_score  ref_free_redundancy  \
# 2  chunk_1024  0.686555   0.76450             0.571906                  0.0
# 0    baseline  0.679419   0.75700             0.576636                  0.0
# 3        hier  0.678389   0.73350             0.623626                  0.0
# 1   chunk_256  0.676258   0.74475             0.595419                  0.0
# 4  matryoshka  0.647753   0.72100             0.627007                  0.0
#
#    latency_s
# 2  20.016812
# 0  20.225371
# 3  37.767845
# 1  25.289667
# 4  18.127856

# %%
cfg_hybrid_rerank = RAGConfig(
    name="hybrid_rerank",
    chunking=ChunkingConfig(chunk_size=256, chunk_overlap=50),
    retrieval=RetrievalConfig(top_k=5, overfetch_k=15, mode='hybrid', use_reranker=True),
    qdrant_collection="scifact_hybrid_rerank",
    recreate_collection=True
)
run_retrieval(cfg_hybrid_rerank, "main", "hybrid_rerank")
show_leaderboard("retrieval", "main")
# Out:
# LLM is explicitly disabled. Using MockLLM.
# /tmp/ipython-input-1409258979.py:8: UserWarning: Local mode is not recommended for collections with more than 20,000 points. Collection <scifact_hier> contains 21037 points. Consider using Qdrant in Docker or Qdrant Cloud for better performance with large datasets.
#   client = QdrantClient(path=QDRANT_PATH)
# Parsing nodes:   0%|          | 0/5183 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/926 [00:00<?, ?it/s]
# DEBUG:bm25s:Building index from IDs objects
# Retr hybrid_rerank:   0%|          | 0/200 [00:00<?, ?it/s]
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#         run_name    ndcg@k  recall@k  ref_free_mean_score  \
# 2     chunk_1024  0.686555  0.764500             0.571906
# 5  hybrid_rerank  0.681326  0.757083             0.027289
# 0       baseline  0.679419  0.757000             0.576636
# 3           hier  0.678389  0.733500             0.623626
# 1      chunk_256  0.676258  0.744750             0.595419
# 4     matryoshka  0.647753  0.721000             0.627007
#
#    ref_free_redundancy  latency_s
# 2                  0.0  20.016812
# 5                  0.0  24.112064
# 0                  0.0  20.225371
# 3                  0.0  37.767845
# 1                  0.0  25.289667
# 4                  0.0  18.127856
# Embeddings have been explicitly disabled. Using MockEmbedding.
#
# 🏆 LEADERBOARD [RETRIEVAL | MAIN] 🏆
#         run_name    ndcg@k  recall@k  ref_free_mean_score  \
# 2     chunk_1024  0.686555  0.764500             0.571906
# 5  hybrid_rerank  0.681326  0.757083             0.027289
# 0       baseline  0.679419  0.757000             0.576636
# 3           hier  0.678389  0.733500             0.623626
# 1      chunk_256  0.676258  0.744750             0.595419
# 4     matryoshka  0.647753  0.721000             0.627007
#
#    ref_free_redundancy  latency_s
# 2                  0.0  20.016812
# 5                  0.0  24.112064
# 0                  0.0  20.225371
# 3                  0.0  37.767845
# 1                  0.0  25.289667
# 4                  0.0  18.127856

# %% [markdown]
# ## Task 3: Generator Tuning (Prompt Engineering) (1 балл)
#
# Качество ретривала (nDCG) мы оптимизировали. Теперь фокус на Генераторе.
#
# **Задание:**
# Модифицируйте `prompt_template` в `LLMConfig`. Цель — максимизировать метрики **Faithfulness** и **Answer Relevancy**.
# Рекомендуемые техники:
# *   **Role Prompting:** ("You are an expert scientist...")
# *   **Constraint Enforcement:** ("Answer ONLY based on the context. If unsure, say 'I don't know'.")
# *   **Chain-of-Thought:** ("Let's analyze the context step by step...")

# %%
# TODO: Create Prompt Config
# cfg_prompt = ...
# run_e2e(cfg_prompt, "main", "prompt_tuned")
# show_leaderboard("e2e", "main")

# %%
cfg_prompt = RAGConfig(
    name="prompt_tuned",
    chunking=ChunkingConfig(chunk_size=1024, chunk_overlap=50),
    retrieval=RetrievalConfig(top_k=5, overfetch_k=15, mode='hybrid', use_reranker=True),
    llm=LLMConfig(prompt_template="You are an expert scientist..."),
    qdrant_collection="scifact_prompt_tuned"
)

run_e2e(cfg_prompt, "main", "prompt_tuned")
show_leaderboard("e2e", "main")
# Out:
# LLM is explicitly disabled. Using MockLLM.
# /tmp/ipython-input-1409258979.py:8: UserWarning: Local mode is not recommended for collections with more than 20,000 points. Collection <scifact_hier> contains 21037 points. Consider using Qdrant in Docker or Qdrant Cloud for better performance with large datasets.
#   client = QdrantClient(path=QDRANT_PATH)
# Retrieving Contexts:   0%|          | 0/10 [00:00<?, ?it/s]
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/99.6M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ✅ Generations saved to /content/artifacts/logs/generations_prompt_tuned_main.json
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Judging prompt_tuned:   0%|          | 0/10 [00:00<?, ?it/s]
# 🏆 LEADERBOARD [E2E | MAIN] 🏆
#        run_name  faithfulness  answer_relevancy   latency_s
# 6  prompt_tuned           0.2               0.0  241.463424
# 🏆 LEADERBOARD [E2E | MAIN] 🏆
#        run_name  faithfulness  answer_relevancy   latency_s
# 6  prompt_tuned           0.2               0.0  241.463424

# %%
cfg_prompt = RAGConfig(
    name="prompt_tuned",
    chunking=ChunkingConfig(chunk_size=256, chunk_overlap=50),
    retrieval=RetrievalConfig(top_k=5, overfetch_k=15),
    llm=LLMConfig(prompt_template="Answer ONLY based on the context. If unsure, say 'I don't know'."),
    qdrant_collection="scifact_prompt_tuned"
)

run_e2e(cfg_prompt, "main", "prompt_tuned")
show_leaderboard("e2e", "main")
# Out:
# LLM is explicitly disabled. Using MockLLM.
# /tmp/ipython-input-1409258979.py:8: UserWarning: Local mode is not recommended for collections with more than 20,000 points. Collection <scifact_hier> contains 21037 points. Consider using Qdrant in Docker or Qdrant Cloud for better performance with large datasets.
#   client = QdrantClient(path=QDRANT_PATH)
# Retrieving Contexts:   0%|          | 0/10 [00:00<?, ?it/s]
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]
# ✅ Generations saved to /content/artifacts/logs/generations_prompt_tuned_main.json
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Judging prompt_tuned:   0%|          | 0/10 [00:00<?, ?it/s]
# 🏆 LEADERBOARD [E2E | MAIN] 🏆
#        run_name  faithfulness  answer_relevancy   latency_s
# 7  prompt_tuned           0.4               0.0  243.304298
# 6  prompt_tuned           0.2               0.0  241.463424
# 🏆 LEADERBOARD [E2E | MAIN] 🏆
#        run_name  faithfulness  answer_relevancy   latency_s
# 7  prompt_tuned           0.4               0.0  243.304298
# 6  prompt_tuned           0.2               0.0  241.463424

# %%
cfg_prompt = RAGConfig(
    name="hybrid_rerank",
    chunking=ChunkingConfig(chunk_size=256, chunk_overlap=50),
    retrieval=RetrievalConfig(top_k=5, overfetch_k=15),
    llm=LLMConfig(prompt_template="Let's analyze the context step by step..."),
    qdrant_collection="scifact_hybrid_rerank"
)

run_e2e(cfg_prompt, "main", "prompt_tuned")
show_leaderboard("e2e", "main")
# Out:
# LLM is explicitly disabled. Using MockLLM.
# /tmp/ipython-input-1409258979.py:8: UserWarning: Local mode is not recommended for collections with more than 20,000 points. Collection <scifact_hier> contains 21037 points. Consider using Qdrant in Docker or Qdrant Cloud for better performance with large datasets.
#   client = QdrantClient(path=QDRANT_PATH)
# Retrieving Contexts:   0%|          | 0/10 [00:00<?, ?it/s]
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]
# ✅ Generations saved to /content/artifacts/logs/generations_prompt_tuned_main.json
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Judging prompt_tuned:   0%|          | 0/10 [00:00<?, ?it/s]
# 🏆 LEADERBOARD [E2E | MAIN] 🏆
#        run_name  faithfulness  answer_relevancy   latency_s
# 7  prompt_tuned           0.4               0.0  243.304298
# 8  prompt_tuned           0.3               0.0  245.051581
# 6  prompt_tuned           0.2               0.0  241.463424
# 🏆 LEADERBOARD [E2E | MAIN] 🏆
#        run_name  faithfulness  answer_relevancy   latency_s
# 7  prompt_tuned           0.4               0.0  243.304298
# 8  prompt_tuned           0.3               0.0  245.051581
# 6  prompt_tuned           0.2               0.0  241.463424

# %%
cfg_prompt = RAGConfig(
    name="prompt_tuned",
    chunking=ChunkingConfig(chunk_size=1024, chunk_overlap=50),
    retrieval=RetrievalConfig(top_k=5, overfetch_k=15, mode="hybrid", use_reranker=True, rerank_top_n=5),
    llm=LLMConfig(
        prompt_template=(
            "You are an expert scientist.\n"
            "Answer the question using ONLY the context.\n"
            "If the context is insufficient, answer exactly: I don't know.\n"
            "Keep the answer short (1-3 sentences).\n\n"
            "Context:\n{context_str}\n\n"
            "Question:\n{query_str}\n\n"
            "Answer:"
        )
    ),
    qdrant_collection="scifact_prompt_tuned"
)

run_e2e(cfg_prompt, "main", "prompt_tuned")
show_leaderboard("e2e", "main")
# Out:
# LLM is explicitly disabled. Using MockLLM.
# /tmp/ipython-input-1409258979.py:8: UserWarning: Local mode is not recommended for collections with more than 20,000 points. Collection <scifact_hier> contains 21037 points. Consider using Qdrant in Docker or Qdrant Cloud for better performance with large datasets.
#   client = QdrantClient(path=QDRANT_PATH)
# Parsing nodes:   0%|          | 0/5183 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/2048 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/1099 [00:00<?, ?it/s]
# DEBUG:bm25s:Building index from IDs objects
# Retrieving Contexts:   0%|          | 0/10 [00:00<?, ?it/s]
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]
# ✅ Generations saved to /content/artifacts/logs/generations_prompt_tuned_main.json
# Embeddings have been explicitly disabled. Using MockEmbedding.
# Judging prompt_tuned:   0%|          | 0/10 [00:00<?, ?it/s]
# 🏆 LEADERBOARD [E2E | MAIN] 🏆
#        run_name  faithfulness  answer_relevancy   latency_s
# 9  prompt_tuned           0.5               0.7  323.455169
# 7  prompt_tuned           0.4               0.0  243.304298
# 8  prompt_tuned           0.3               0.0  245.051581
# 6  prompt_tuned           0.2               0.0  241.463424
# 🏆 LEADERBOARD [E2E | MAIN] 🏆
#        run_name  faithfulness  answer_relevancy   latency_s
# 9  prompt_tuned           0.5               0.7  323.455169
# 7  prompt_tuned           0.4               0.0  243.304298
# 8  prompt_tuned           0.3               0.0  245.051581
# 6  prompt_tuned           0.2               0.0  241.463424

# %% [markdown]
# ## 4. Final Challenge
#
# Выберите одну лучшую конфигурацию по совокупности метрик. Запустите её на отложенной выборке **Challenge Split**.
# Сравните результаты с Baseline на этом же сплите.

# %%
# TODO: Final Evaluation
# run_retrieval(best_cfg, "challenge", "final_submission")
# run_e2e(best_cfg, "challenge", "final_submission")

print("FINAL RESULTS:")
show_leaderboard("retrieval", "challenge")
show_leaderboard("e2e", "challenge")
# Out:
# FINAL RESULTS:
